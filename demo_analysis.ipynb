# %%
import pandas as pd

# %%
#2016~2021の連結決算データを抽出
df_finance = pd.read_csv("./data/financial_data/finance_info_2016_2021.csv", encoding="shift_jis")
df_stock = pd.read_csv("./data/financial_data/stock_info_2016_2021_monthly.csv", encoding="shift_jis")

# %%
df_finance.head()
# Out:
#    日経会社コード           企業名称      決算期  決算種別  連結基準  <ヘッダー項目>決算月数  \
# 0    31504  リンクアンドモチベーション  2016/12    10     3            12
# 1    31504  リンクアンドモチベーション  2016/12    10     1            12
# 2    31504  リンクアンドモチベーション  2017/12    10     3            12
# 3    31504  リンクアンドモチベーション  2017/12    10     1            12
# 4    31504  リンクアンドモチベーション  2018/12    10     3            12
#
#    <ヘッダー項目>連結・単独フラグ  <ヘッダー項目>日経業種：コード  <ヘッダー項目>本社所在地：コード <ヘッダー項目>本社所在地：日本語名称  \
# 0                 2            271704                 13                 東京都
# 1                 2            271704                 13                 東京都
# 2                 2            271704                 13                 東京都
# 3                 2            271704                 13                 東京都
# 4                 2            271704                 13                 東京都
#
#    ...  <販売費及び一般管理費（四半期会計期間）>【販管費】開発費・試験研究費［３ヵ月］  \
# 0  ...                                       NaN
# ...

# %%
df_stock.head()
# Out:
#         期間      日経平均    TOPIX   東証2部総合   東証マザーズ  JASDAQ  株式コード  上場コード  \
# 0  2016/01  17518.30  1432.07  4482.16   831.34  108.93   2170   11.0
# 1  2016/02  16026.76  1297.85  4216.15   838.67  103.37   2170   11.0
# 2  2016/03  16758.67  1347.20  4381.42  1020.80  110.02   2170   11.0
# 3  2016/04  16666.05  1340.55  4292.72  1131.56  108.86   2170   11.0
# 4  2016/05  17234.98  1379.80  4393.47  1144.64  113.88   2170   11.0
#
#             銘柄名称  時価総額（発行済み株式数ベース）  ...  無償増資：割当率：親株比率  無償増資：割当率：子株比率  \
# 0  リンクアンドモチベーション      1.300282e+10  ...            0.0            0.0
# 1  リンクアンドモチベーション      1.345509e+10  ...            0.0            0.0
# 2  リンクアンドモチベーション      1.605566e+10  ...            0.0            0.0
# 3  リンクアンドモチベーション      1.594259e+10  ...            0.0            0.0
# 4  リンクアンドモチベーション      1.786474e+10  ...            0.0            0.0
#
#    無償増資：割当日  無償増資：割当率  減資：発生フラグ  減資：割当率：親株比率  減資：割当率：子株比率  減資：確定日  減資：割当率  \
# ...

# %%
print(df_finance.describe())
# Out:
#             日経会社コード   決算種別        連結基準  <ヘッダー項目>決算月数  <ヘッダー項目>連結・単独フラグ  \
# count    413.000000  413.0  413.000000    413.000000             413.0
# mean   28382.285714   10.0    1.251816     11.997579               2.0
# std    12803.564051    0.0    0.664296      0.283004               0.0
# min     1636.000000   10.0    1.000000      8.000000               2.0
# 25%    25965.000000   10.0    1.000000     12.000000               2.0
# 50%    31276.000000   10.0    1.000000     12.000000               2.0
# 75%    32249.000000   10.0    1.000000     12.000000               2.0
# max    55192.000000   10.0    3.000000     16.000000               2.0
#
#        <ヘッダー項目>日経業種：コード  <ヘッダー項目>本社所在地：コード  <基本項目>事業年度開始年月日［累計］  <基本項目>連結子会社数  \
# count        413.000000         413.000000         4.130000e+02    390.000000
# mean      269297.222760          14.656174         2.017709e+07     13.174359
# std        16597.703749           5.192689         1.633419e+04     29.635235
# ...

# %%
print(df_finance.columns)
# Out:
# Index(['日経会社コード', '企業名称', '決算期', '決算種別', '連結基準', '<ヘッダー項目>決算月数',
#        '<ヘッダー項目>連結・単独フラグ', '<ヘッダー項目>日経業種：コード', '<ヘッダー項目>本社所在地：コード',
#        '<ヘッダー項目>本社所在地：日本語名称',
#        ...
#        '<販売費及び一般管理費（四半期会計期間）>【販管費】開発費・試験研究費［３ヵ月］',
#        '<販売費及び一般管理費（四半期会計期間）>【販管費】保証修理費［３ヵ月］',
#        '<販売費及び一般管理費（四半期会計期間）>【販管費】その他販売費及び一般管理費［３ヵ月］',
#        '<販売費及び一般管理費（四半期会計期間）>【販管費】販売費及び一般管理費明細合計［３ヵ月］',
#        '<【更新中止】その他>従業員数（うち正社員）', '<【更新中止】その他>従業員数（うち常勤嘱託）',
#        '<【更新中止】その他>従業員数（うち受入社員）', '<【更新中止】その他>従業員数（うち休職者等）',
#        '<【更新中止】その他>従業員数（うち出向者）', '<【更新中止】その他>従業員数（うちその他）'],
#       dtype='object', length=170)

# %%
df_stock.describe()
# Out:
#                日経平均        TOPIX       東証2部総合       東証マザーズ       JASDAQ  \
# count   7906.000000  7906.000000  7906.000000  7906.000000  7906.000000
# mean   21623.360299  1615.150746  6320.409851  1027.286866   152.921343
# std     3333.701084   171.203914  1026.304998   146.528149    24.251426
# min    15575.920000  1245.820000  4136.330000   620.090000   103.370000
# 25%    19196.740000  1511.860000  5753.310000   907.560000   133.430000
# 50%    21710.000000  1611.900000  6570.910000  1030.460000   155.290000
# 75%    22977.130000  1753.290000  7213.640000  1150.060000   172.230000
# max    29178.800000  1954.000000  7678.150000  1313.380000   189.080000
#
#              株式コード        上場コード  時価総額（発行済み株式数ベース）          決算月  \
# count  7906.000000  6010.000000      6.009000e+03  6010.000000
# mean   4792.576271    18.860233      2.175480e+11     5.502662
# std    1717.369597    21.993110      9.361338e+11     3.797339
# min    2170.000000    11.000000      1.698000e+09     1.000000
# ...

# %%
df_stock.columns
# Out:
# Index(['期間', '日経平均', 'TOPIX', '東証2部総合', '東証マザーズ', 'JASDAQ', '株式コード', '上場コード',
#        '銘柄名称', '時価総額（発行済み株式数ベース）', '決算月', '発行済み株式数（権利落ベース）', '日経平均採用区分',
#        '日経３００採用区分', '日経５００採用区分', '東証：上場日', 'ジャスダック：上場日', '株式分割：発生フラグ',
#        '株式分割：確定日', '株式分割：比率', '株式併合：発生フラグ', '株式併合：割当率：親株比率', '株式併合：割当率：子株比率',
#        '株式併合：確定日', '有償増資：発生フラグ', '有償増資：割当率：親株比率', '有償増資：割当率：子株比率', '有償増資：割当日',
#        '有償増資：払込期日', '無償増資：発生フラグ', '無償増資：割当率：親株比率', '無償増資：割当率：子株比率', '無償増資：割当日',
#        '無償増資：割当率', '減資：発生フラグ', '減資：割当率：親株比率', '減資：割当率：子株比率', '減資：確定日',
#        '減資：割当率', '直近配当額'],
#       dtype='object')

# %%
# Out:
# 日経会社コード                                                16552
# 企業名称                                                   16552
# 決算期                                                    16552
# 決算種別                                                   16552
# 連結基準                                                   16552
# <基本項目>１株当たり利益［累計］                                      15924
# <基本項目>１株当たり純資産                                         15923
# <貸借対照表（資産）>流動資産                                        16511
# <貸借対照表（負債）>流動負債                                        16511
# <貸借対照表（純資産）>純資産合計／資本合計                                 16545
# <貸借対照表（純資産）>株主資本                                       15667
# <貸借対照表（純資産）>資本金                                        16422
# <損益計算書（期首からの累計期間）>売上高・営業収益［累計］                         16519
# <損益計算書（期首からの累計期間）>売上高・営業収益（うち金融収益）［累計］                   172
# <損益計算書（期首からの累計期間）>営業費用［累計］                             16503
# ...
