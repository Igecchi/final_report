# %%
import pandas as pd

# %%
#2014~2019の連結決算データを抽出
df_data = pd.read_csv("demo_data.csv", encoding="shift_jis")
df_data.head()
# Out:
#    日経会社コード 企業名称      決算期  決算種別  連結基準  <基本項目>１株当たり利益［累計］  <基本項目>１株当たり純資産  \
# 0        1   極洋  2014/03    10     1              28.26          187.57
# 1        1   極洋  2015/03    10     1              23.17          215.65
# 2        1   極洋  2016/03    10     1              17.13          214.97
# 3        1   極洋  2017/03    10     1             230.66         2378.09
# 4        1   極洋  2018/03    10     1             304.29         2679.00
#
#    <貸借対照表（資産）>流動資産  <貸借対照表（負債）>流動負債  <貸借対照表（純資産）>純資産合計／資本合計  ...  \
# 0          63033.0          41031.0                 19930.0  ...
# 1          69860.0          46460.0                 23069.0  ...
# 2          70426.0          40835.0                 23065.0  ...
# 3          72351.0          45195.0                 25391.0  ...
# 4          81218.0          52100.0                 29243.0  ...
#
#    <損益計算書（期首からの累計期間）>営業利益［累計］  <損益計算書（期首からの累計期間）>収益合計（性質別分類）［累計］  \
# 0                      2915.0                                NaN
# ...

# %%
df_data.columns
# Out:
# Index(['日経会社コード', '企業名称', '決算期', '決算種別', '連結基準', '<基本項目>１株当たり利益［累計］',
#        '<基本項目>１株当たり純資産', '<貸借対照表（資産）>流動資産', '<貸借対照表（負債）>流動負債',
#        '<貸借対照表（純資産）>純資産合計／資本合計', '<貸借対照表（純資産）>株主資本', '<貸借対照表（純資産）>資本金',
#        '<損益計算書（期首からの累計期間）>売上高・営業収益［累計］',
#        '<損益計算書（期首からの累計期間）>売上高・営業収益（うち金融収益）［累計］', '<損益計算書（期首からの累計期間）>営業費用［累計］',
#        '<損益計算書（期首からの累計期間）>売上原価・営業原価［累計］',
#        '<損益計算書（期首からの累計期間）>割賦販売未実現利益・返品調整引当金差額／返品調整引当金差額［累計］',
#        '<損益計算書（期首からの累計期間）>売上総利益［累計］', '<損益計算書（期首からの累計期間）>販売費及び一般管理費［累計］',
#        '<損益計算書（期首からの累計期間）>金融費用［累計］', '<損益計算書（期首からの累計期間）>営業利益［累計］',
#        '<損益計算書（期首からの累計期間）>収益合計（性質別分類）［累計］',
#        '<損益計算書（期首からの累計期間）>費用合計（性質別分類）［累計］', '<損益計算書（期首からの累計期間）>営業外収益［累計］',
#        '<損益計算書（期首からの累計期間）>受取利息・配当金［累計］', '<損益計算書（期首からの累計期間）>有価証券売却益［累計］',
#        '<損益計算書（期首からの累計期間）>有価証券評価益［累計］', '<損益計算書（期首からの累計期間）>デリバティブ評価益［累計］',
#        '<損益計算書（期首からの累計期間）>その他資産処分益・評価益［累計］', '<損益計算書（期首からの累計期間）>営業外費用［累計］'],
#       dtype='object')

# %%
print(df_data.count())
df_data.describe()
# Out:
# 日経会社コード                                                16552
# 企業名称                                                   16552
# 決算期                                                    16552
# 決算種別                                                   16552
# 連結基準                                                   16552
# <基本項目>１株当たり利益［累計］                                      15924
# <基本項目>１株当たり純資産                                         15923
# <貸借対照表（資産）>流動資産                                        16511
# <貸借対照表（負債）>流動負債                                        16511
# <貸借対照表（純資産）>純資産合計／資本合計                                 16545
# <貸借対照表（純資産）>株主資本                                       15667
# <貸借対照表（純資産）>資本金                                        16422
# <損益計算書（期首からの累計期間）>売上高・営業収益［累計］                         16519
# <損益計算書（期首からの累計期間）>売上高・営業収益（うち金融収益）［累計］                   172
# <損益計算書（期首からの累計期間）>営業費用［累計］                             16503
# ...
